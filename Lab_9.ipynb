# %% [markdown]
# <a href="https://colab.research.google.com/github/241b260/algolab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    visited = []

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous


def reconstruct_path(previous, start, end):
    path = []
    current = end
    while current is not None:
        path.insert(0, current)
        current = previous[current]
    if path[0] == start:
        return path
    else:
        return None


graph = {}
n = int(input("Enter number of nodes: A"))
for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}

m = int(input("Enter number of edges: "))
for i in range(m):
    u = input("Enter source node: ")
    v = input("Enter destination node: ")
    w = int(input("Enter weight: "))
    graph[u][v] = w
    graph[v][u] = w


start_node = input("Enter starting node: ")
distances, previous = dijkstra(graph, start_node)

print("\nShortest paths from", start_node)
for node in graph:
    path = reconstruct_path(previous, start_node, node)
    if path:
        print(f"Path to {node}: {' -> '.join(path)} | Distance = {distances[node]}")
    else:
        print(f"No path to {node}")
# Out:
# Enter number of nodes: 6
# Enter node 1 name: A
# Enter node 2 name: B
# Enter node 3 name: C
# Enter node 4 name: D
# Enter node 5 name: E
# Enter node 6 name: F
# Enter number of edges: 9
# Enter source node: A
# Enter destination node: B
# Enter weight: 6
# Enter source node: A
# Enter destination node: C
# Enter weight: 5
# Enter source node: A
# Enter destination node: D
# Enter weight: 2
# Enter source node: B
# Enter destination node: D
# Enter weight: 4
# Enter source node: C
# Enter destination node: D
# Enter weight: 5
# Enter source node: C
# Enter destination node: E
# Enter weight: 2
# Enter source node: C
# Enter destination node: F
# Enter weight: 1
# Enter source node: D
# Enter destination node: E
# Enter weight: 6
# Enter source node: E
# Enter destination node: F
# Enter weight: 8
# Enter starting node: F
#
# Shortest paths from F
# Path to A: F -> C -> A | Distance = 6
# Path to B: F -> C -> D -> B | Distance = 10
# Path to C: F -> C | Distance = 1
# Path to D: F -> C -> D | Distance = 6
# Path to E: F -> C -> E | Distance = 3
# Path to F: F | Distance = 0
